# %%
import numpy as np
import random as rand
import matplotlib.pyplot as plt
import scipy as sci

#1: create functions for each of my temperature profiles:

def const_density(R_star, density, r, high_mass = True):
    M_sun = 1.989*10**30 #[kg]
    G = 6.673*10**-11 # [m^3 kg^-1 s^-2]
    R_sun = 6.955*10**8 #[m]
    mu = 1.30
    mp = 1.673*10**-27 # [kg] 
    k = 1.381*10**-23 # [m^2 kg s^-2 K^-1]
    
    if high_mass == True:
        T_r = (((-2*(density**2)*G*r**2)/3)+((3*G*M_sun)/(8*np.pi*R_star**4))*((R_star/(1.33*R_sun))**(-0.55*2)))*((mu*mp)/k*density)
    if high_mass == False:
        T_r = (((-2*(density**2)*G*r**2)/3)+((3*G*M_sun)/(8*np.pi*R_star**4))*((R_star/(1.06*R_sun))**(-0.945*2)))*((mu*mp)/k*density)
    
    return T_r

def test_temp_profile(r_Rstar, T_c):
   
    T_r = T_c/(r_Rstar**0.1)
    
    return T_r

def const_density_beta(R_star, M_star, density, r):
    mu = 1.30
    mp = 1.673*10**-27 # [kg] 
    k = 1.381*10**-23 # [m^2 kg s^-2 K^-1]
    G = 6.673*10**-11 # [m^3 kg^-1 s^-2]
    
    T_r = ((mu*mp)/(density*k))*((((-2*np.pi)/3)*G*density**2*r**2)+(3*G*M_star**2)/(8*np.pi*R_star**4))
    
    return T_r

# %% [markdown]
# Density Profiles

# %%
#y
def density_alpha(radius):
    p0 = 1000
    p = p0
    return p
def density_beta(radius):
    p0 = 1000
    p = p0/radius
    return p
def density_gamma(radius):
    p0 = 1000
    p = p0/radius**2
    return p

# %% [markdown]
# Temperature Profies - derived from density profiles

# %%
#y
def temp_alpha(radius, M_star, R_star):
    G = 6.67*10**-31
    k = 1.38*10**-23
    mu = 1.3
    mp = 1.67*10**-27
    
    P_C = (3/8)*G*((M_star**2)/(np.pi*R_star**4))
    T_r = (mu*mp/(density_alpha(radius))*k)*(((-2/3)*np.pi*G*(density_alpha(radius))**2*radius**2)+((P_C)))

# %% [markdown]
# Kramer's Law considering $K_{ff}$ and $K_{bf}$

# %%
#y
def kramer_law(radius, density, temperature, X, Y, Z):
    C1 = 4.3*10**25
    C2 = 3.7*10**22
    K_r = (((C1*(1+X))+(C2*(X+Y)))/2)*density(radius)*temperature(radius)**-3.5
    return K_r

# %% [markdown]
# Mean free path

# %%
#y
def mean_fre_path(kramer_funcn, density_funcn, radius):
    l = 1/(kramer_funcn(r)*density_funcn(r))
    return l

# %%
radius = np.arange(0,10**10, 1000)
plt.title('this temperature profile lies')
plt.plot(radius, const_density(10**6, 10**30, radius))
plt.show()

plt.plot(np.arange(0.001, 1, 0.001), test_temp_profile(np.arange(0.001, 1, 0.001), 10**6))
plt.show()

plt.plot(np.arange(0,10**10, 1000), const_density_beta(6.955*10**8, 1.989*10**30,1000, np.arange(0,10**10, 1000)))
plt.show()

# %%
def mean_free_path(central_temp, density, temp_profile, r, alpha):
    l = alpha*r/(density*(temp_profile(r,central_temp))**-3.5)
    return l

# %%
from mpl_toolkits import mplot3d
N = 1000
r = (1*10)**-10
x = []
y = []
z = []
for n in range(N):
    theta = rand.uniform(0,2*np.pi)
    phi = rand.uniform(0,2*np.pi)
    l = mean_free_path(10**6, 1000, test_temp_profile, r, 10**-12)
    l = 10**-12*r/(1000*(const_density_beta(6.955*10**8, 1.989*10**30,1000, r))**3.5)
    r = r+l
    X = r * np.sin(phi) * np.cos(theta)
    Y = r * np.sin(phi) * np.sin(theta)
    Z = r * np.cos(phi)
    x.append(X)
    y.append(Y)
    z.append(Z)
    #if r > 1:
     #   break

fig = plt.figure()
ax = plt.subplot(111, projection='3d')
ax.plot(x,y,z, '.')
plt.show()

# %%
from mpl_toolkits import mplot3d
N = 1000

x = 0
y = 0
z = 0

x_val = [0]
y_val = [0]
z_val = [0]

r_star = 
for n in range(N):
    theta = rand.uniform(0,2*np.pi)
    phi = rand.uniform(0,2*np.pi)
    l = mean_free_path(kramer_funcn(r, density, temperature, metallicity info), density_funcn(r), r)
    
    dx = l * np.sin(phi) * np.cos(theta)
    dy = l * np.sin(phi) * np.sin(theta)
    dz = l * np.cos(phi)
    
    x = x + dx
    y = y + dy
    z = z + dz

    x.append(x)
    y.append(y)
    z.append(z)
    
    r = (x**2 + y**2 + z**2)**0.5
    
    if r >= r_star:
        break
